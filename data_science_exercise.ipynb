# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# Load the iris dataset
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Create random columns
iris_df['random_column_1'] = np.random.rand(len(iris_df))
iris_df['random_column_2'] = np.random.randint(0, 100, size=len(iris_df))

# Create categorical columns
iris_df['category'] = np.random.choice(['A', 'B', 'C'], size=len(iris_df))

# Display the first few rows of the dataframe
print(iris_df.head())

# %% [markdown]
# ## Data Wrangling Questions
# 1. How would you aggregate the data to show the mean of the random columns grouped by the categorical column?
# 2. What steps would you take to handle missing values in the random columns?
# 3. If you were to merge this dataframe with another dataset, what considerations would you make regarding the merge key?
#
# ## Ethics Questions
# 1. Discuss the potential ethical implications of using generative AI to automate decision-making in hiring processes.
# 2. How can companies ensure that their use of generative AI respects employee privacy and data security?
